# %%
# Import Libs
import os
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from sklearn.model_selection import train_test_split

# %%
# Images folder
output_dir = '../images'

# %%
# Reading Dataset
data = pd.read_csv('../data/AmesHousing.csv')
data.head()
# Out:
#    Order        PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street  \
# 0      1  526301100           20        RL         141.0     31770   Pave
# 1      2  526350040           20        RH          80.0     11622   Pave
# 2      3  526351010           20        RL          81.0     14267   Pave
# 3      4  526353030           20        RL          93.0     11160   Pave
# 4      5  527105010           60        RL          74.0     13830   Pave
#
#   Alley Lot Shape Land Contour  ... Pool Area Pool QC  Fence Misc Feature  \
# 0   NaN       IR1          Lvl  ...         0     NaN    NaN          NaN
# 1   NaN       Reg          Lvl  ...         0     NaN  MnPrv          NaN
# 2   NaN       IR1          Lvl  ...         0     NaN    NaN         Gar2
# 3   NaN       Reg          Lvl  ...         0     NaN    NaN          NaN
# 4   NaN       IR1          Lvl  ...         0     NaN  MnPrv          NaN
#
#   Misc Val Mo Sold Yr Sold Sale Type  Sale Condition  SalePrice
# ...

# %%
# Data Info
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2930 entries, 0 to 2929
# Data columns (total 82 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Order            2930 non-null   int64
#  1   PID              2930 non-null   int64
#  2   MS SubClass      2930 non-null   int64
#  3   MS Zoning        2930 non-null   object
#  4   Lot Frontage     2440 non-null   float64
#  5   Lot Area         2930 non-null   int64
#  6   Street           2930 non-null   object
#  7   Alley            198 non-null    object
#  8   Lot Shape        2930 non-null   object
#  9   Land Contour     2930 non-null   object
#  10  Utilities        2930 non-null   object
#  11  Lot Config       2930 non-null   object
#  12  Land Slope       2930 non-null   object
#  13  Neighborhood     2930 non-null   object
#  14  Condition 1      2930 non-null   object
#  15  Condition 2      2930 non-null   object
# ...

# %%
# Data Describe
data.describe()
# Out:
#             Order           PID  MS SubClass  Lot Frontage       Lot Area  \
# count  2930.00000  2.930000e+03  2930.000000   2440.000000    2930.000000
# mean   1465.50000  7.144645e+08    57.387372     69.224590   10147.921843
# std     845.96247  1.887308e+08    42.638025     23.365335    7880.017759
# min       1.00000  5.263011e+08    20.000000     21.000000    1300.000000
# 25%     733.25000  5.284770e+08    20.000000     58.000000    7440.250000
# 50%    1465.50000  5.354536e+08    50.000000     68.000000    9436.500000
# 75%    2197.75000  9.071811e+08    70.000000     80.000000   11555.250000
# max    2930.00000  1.007100e+09   190.000000    313.000000  215245.000000
#
#        Overall Qual  Overall Cond   Year Built  Year Remod/Add  Mas Vnr Area  \
# count   2930.000000   2930.000000  2930.000000     2930.000000   2907.000000
# mean       6.094881      5.563140  1971.356314     1984.266553    101.896801
# ...

# %%
# Checking nulls
data.isnull().sum()
# Out:
# Order               0
# PID                 0
# MS SubClass         0
# MS Zoning           0
# Lot Frontage      490
#                  ...
# Mo Sold             0
# Yr Sold             0
# Sale Type           0
# Sale Condition      0
# SalePrice           0
# Length: 82, dtype: int64

# %%
# Histogram Sales Prices
sns.set(style="whitegrid")
plt.figure(figsize=(10, 6))
sns.histplot(data['SalePrice'], bins=30, kde=True)
plt.title('Property Prices Distribution')
plt.xlabel('Price')
plt.ylabel('Frequency')
plt.savefig(os.path.join(output_dir, 'Property_Prices_Distribution.png'))
plt.show()

# %%
# Relation between prices and lot Area
plt.figure(figsize=(10, 6))
sns.scatterplot(data=data, x='Lot Area', y='SalePrice')
plt.title('Relation between Lot Area vs Sale Price')
plt.xlabel('Lot Area')
plt.ylabel('Price')
plt.savefig(os.path.join(output_dir, 'Relation_between_Lot_Area_vs_SalePrice.png'))
plt.show()

# %%
# Filter numeric colmuns
numeric_data = data.select_dtypes(include=[np.number])

# %%
# Correlation Matrix only numeric columns
plt.figure(figsize=(30, 20))
correlation_matrix = numeric_data.corr()
filtered_corr_matrix = correlation_matrix[(correlation_matrix.abs() >= 0.5) & (correlation_matrix != 1.0)]

sns.heatmap(filtered_corr_matrix, annot=True, cmap='coolwarm', fmt='.2f', linewidths=0.5, mask=np.isnan(filtered_corr_matrix))
plt.title('Correlation Matrix')
plt.savefig(os.path.join(output_dir, 'Correlation_Matrix.png'))
plt.show()

# %%
# Filter categorycal columns
categorical_data = data.select_dtypes(include=['object', 'category'])
print(categorical_data.head())
# Out:
#   MS Zoning Street Alley Lot Shape Land Contour Utilities Lot Config  \
# 0        RL   Pave   NaN       IR1          Lvl    AllPub     Corner
# 1        RH   Pave   NaN       Reg          Lvl    AllPub     Inside
# 2        RL   Pave   NaN       IR1          Lvl    AllPub     Corner
# 3        RL   Pave   NaN       Reg          Lvl    AllPub     Corner
# 4        RL   Pave   NaN       IR1          Lvl    AllPub     Inside
#
#   Land Slope Neighborhood Condition 1  ... Garage Type Garage Finish  \
# 0        Gtl        NAmes        Norm  ...      Attchd           Fin
# 1        Gtl        NAmes       Feedr  ...      Attchd           Unf
# 2        Gtl        NAmes        Norm  ...      Attchd           Unf
# 3        Gtl        NAmes        Norm  ...      Attchd           Fin
# 4        Gtl      Gilbert        Norm  ...      Attchd           Fin
#
#   Garage Qual Garage Cond Paved Drive Pool QC  Fence Misc Feature Sale Type  \
# ...

# %%
# Categorycal columns to numeric
data_encoded = pd.get_dummies(data, drop_first=True)

print(data_encoded.head())
# Out:
#    Order        PID  MS SubClass  Lot Frontage  Lot Area  Overall Qual  \
# 0      1  526301100           20         141.0     31770             6
# 1      2  526350040           20          80.0     11622             5
# 2      3  526351010           20          81.0     14267             6
# 3      4  526353030           20          93.0     11160             7
# 4      5  527105010           60          74.0     13830             5
#
#    Overall Cond  Year Built  Year Remod/Add  Mas Vnr Area  ...  \
# 0             5        1960            1960         112.0  ...
# 1             6        1961            1961           0.0  ...
# 2             6        1958            1958         108.0  ...
# 3             5        1968            1968           0.0  ...
# 4             5        1997            1998           0.0  ...
#
#    Sale Type_ConLw  Sale Type_New  Sale Type_Oth  Sale Type_VWD  \
# 0            False          False          False          False
# ...

# %%
# Selecting specific columns to check relations
columns_to_include = ['Overall Qual','Garage Cars','Year Built','Overall Cond','SalePrice']
data_subset = data_encoded[columns_to_include]

plt.figure(figsize=(10, 6))
correlation_matrix = data_subset.corr()

# Filter corr Matrix just with >=0.5 
filtered_corr_matrix = correlation_matrix[(correlation_matrix.abs() >= 0.5) & (correlation_matrix != 1.0)]

sns.heatmap(filtered_corr_matrix, annot=True, cmap='coolwarm', fmt='.2f', linewidths=0.5, mask=np.isnan(filtered_corr_matrix))
plt.title('Corr Matrix (Values > 0.5)')
plt.savefig(os.path.join(output_dir, 'Correlation_Matrix_more05.png'))
plt.show()
