# %%
# Import necessary libraries
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
import joblib

# Load the data
X_train_scaled = np.load('../notebooks/X_train_scaled.npy')
y_train = np.load('../notebooks/y_train.npy')
X_test_scaled = np.load('../notebooks/X_test_scaled.npy')
y_test = np.load('../notebooks/y_test.npy')

# Create the Linear Regression model
lin_reg = LinearRegression()

# Train the model
lin_reg.fit(X_train_scaled, y_train)

# Make predictions
y_pred_train = lin_reg.predict(X_train_scaled)
y_pred_test = lin_reg.predict(X_test_scaled)

# Evaluate the model
print("Linear Regression")
print("Training MSE:", mean_squared_error(y_train, y_pred_train))
print("Training R^2:", r2_score(y_train, y_pred_train))
print("Test MSE:", mean_squared_error(y_test, y_pred_test))
print("Test R^2:", r2_score(y_test, y_pred_test))

# Save the model
joblib.dump(lin_reg, 'linear_regression_model.pkl')
# Out:
# Linear Regression
# Training MSE: 1216803718.3684738
# Training R^2: 0.7953486216775962
# Test MSE: 1441441549.700708
# Test R^2: 0.8202141649638376
# ['linear_regression_model.pkl']

# %%
import matplotlib.pyplot as plt

residuals = y_test - y_pred_test
plt.figure(figsize=(10, 6))
plt.scatter(y_pred_test, residuals, alpha=0.5)
plt.axhline(y=0, color='r', linestyle='--')
plt.xlabel('Predicted Values')
plt.ylabel('Residuals')
plt.title('Residuals vs Predicted Values')
plt.show()
